# %% [markdown]
# ## Vectors and Topics for Fun
# ### Document classification with Gensim
#
# In this tutorial we'll classify movie plots by genre using word embeddings techniques in [gensim](http://radimrehurek.com/gensim/) .
#
# See accompanying slides in this repo.
#
# We will show how to get a __'hello-world'__ first untuned run using 7 techniques:
#
# - Bag of words
#
# - Character n-grams
#
# - TF-IDF
#
# - Averaging word2vec vectors
#
# - doc2vec
#
# - Deep IR
#
# - Word Mover's Distance
#
# The goal of this tutorial is to show the API so you can start tuning them yourself. Model tuning of the models is out of scope of this tutorial.
#
# We will also compare the accuracy of this first 'no tuning'/out of the box run of these techniques. It is in no way an indication of their best peformance that can be achieved with proper tuning. The benefit of the comparison is to manage the expectations.

# %% [markdown]
# ## Requirements
# - Python 3
# - [Google News pre-trained word2vec (1.5 GB)](https://drive.google.com/file/d/0B7XkCwpI5KDYNlNUTTlSS21pQmM/edit?usp=sharing)
# - gensim
# - sklearn
# - pandas
# - matplotlib
# - nltk with English stopwords
# - pyemd
# - 4 GB RAM
# - 8 GB disk space for WMD

# %% [markdown]
# ## Dataset
# We will use MovieLens dataset linked with plots from OMDB. Thanks to [Sujit Pal](http://sujitpal.blogspot.de/2016/04/predicting-movie-tags-from-plots-using.html) for this linking idea. The prepared csv is in this repository. If you wish to link the datasets yourself - see the code in the [blog]((http://sujitpal.blogspot.de/2016/04/predicting-movie-tags-from-plots-using.html).

# %%
import logging
logging.root.handlers = []  # Jupyter messes up logging so needs a reset
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
from smart_open import smart_open
import pandas as pd
import numpy as np
from numpy import random
import gensim
import nltk
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics import accuracy_score, confusion_matrix
import matplotlib.pyplot as plt
from gensim.models import Word2Vec
from sklearn.neighbors import KNeighborsClassifier
from sklearn import linear_model
from nltk.corpus import stopwords
nltk.download('punkt')

# %matplotlib inline
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\shoai\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.

# %% [markdown]
# ## Exploring the data

# %%
df = pd.read_csv('data/tagged_plots_movielens.csv')
df = df.dropna()
df['plot'].apply(lambda x: len(x.split(' '))).sum()
# Out:
# 171156

# %% [markdown]
# The dataset is only __170k__ words. It is quite small but makes sure we don't have to wait a long time for the code to complete.

# %%
my_tags = ['sci-fi' , 'action', 'comedy', 'fantasy', 'animation', 'romance']
df.tag.value_counts().plot(kind="bar", rot=0)
# Out:
# <AxesSubplot:>

# %% [markdown]
# The data is very unbalanced. We have Comedy as majority class.
#
# A naive classifier that predicts everything to be comedy already achieves __40%__ accuracy.

# %% [markdown]
# The language in sci-fi plots differs a lot from action plots, so there should be some signal here.

# %%
df
# Out:
#       Unnamed: 0  movieId                                               plot  \
# 0              0        1  A little boy named Andy loves to be in his roo...
# 1              1        2  When two kids find and play a magical board ga...
# 2              2        3  Things don't seem to change much in Wabasha Co...
# 3              3        6  Hunters and their prey--Neil and his professio...
# 4              4        7  An ugly duckling having undergone a remarkable...
# ...          ...      ...                                                ...
# 2443        2443   148618  Three kids who travel back in time to 65 milli...
# 2444        2444   148624  Top Cat and the gang face a new police chief, ...
# 2445        2445   149088  Raggedy Ann and the rest of the toys in Marcel...
# 2446        2446   149406  Continuing his "legendary adventures of awesom...
# 2447        2447   151451  A romance fantasy humorous situations cleverly...
#
#             tag
# 0     animation
# 1       fantasy
# 2        comedy
# 3        action
# 4       romance
# ...         ...
# 2443  animation
# 2444  animation
# 2445  animation
# 2446     comedy
# 2447    romance
#
# [2427 rows x 4 columns]

# %%
def print_plot(index):
    example = df[df.index == index][['plot', 'tag']].values[0]
    if len(example) > 0:
        print(example[0])
        print('Genre:', example[1])

# %%
print_plot(12)
# Out:
# In a future world devastated by disease, a convict is sent back in time to gather information about the man-made virus that wiped out most of the human population on the planet.
# Genre: sci-fi

# %%
print_plot(15)
# Out:
# Based on the popular video game of the same name "Mortal Kombat" tells the story of an ancient tournament where the best of the best of different Realms fight each other. The goal - ten wins to be able to legally invade the losing Realm. Outworld has so far collected nine wins against Earthrealm, so it's up to Lord Rayden and his fighters to stop Outworld from reaching the final victory...
# Genre: action

# %% [markdown]
# Train/test split of 90/10

# %%
train_data, test_data = train_test_split(df, test_size=0.1, random_state=42)

# %%
len(test_data)
# Out:
# 243

# %%
test_data.tag.value_counts().plot(kind="bar", rot=0)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Model evaluation approach
# We will use confusion matrices to evaluate all classifiers

# %%
def plot_confusion_matrix(cm, title='Confusion matrix', cmap=plt.cm.Blues):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(my_tags))
    target_names = my_tags
    plt.xticks(tick_marks, target_names, rotation=45)
    plt.yticks(tick_marks, target_names)
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
def evaluate_prediction(predictions, target, title="Confusion matrix"):
    print('accuracy %s' % accuracy_score(target, predictions))
    cm = confusion_matrix(target, predictions)
    print('confusion matrix\n %s' % cm)
    print('(row=expected, col=predicted)')
    
    cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    plot_confusion_matrix(cm_normalized, title + ' Normalized')

# %%
def predict(vectorizer, classifier, data):
    data_features = vectorizer.transform(data['plot'])
    predictions = classifier.predict(data_features)
    target = data['tag']
    evaluate_prediction(predictions, target)

# %% [markdown]
# ## Baseline: bag of words, n-grams, tf-idf
# Let's start with some simple baselines before diving into more advanced methods.

# %% [markdown]
# ### Bag of words

# %% [markdown]
# The simplest document feature is just a count of each word occurrence in a document.
#
# We remove stop-words and use NLTK tokenizer then limit our vocabulary to 3k most frequent words.

# %%
def tokenize_text(text):
    tokens = []
    for sent in nltk.sent_tokenize(text):
        for word in nltk.word_tokenize(sent):
            if len(word) < 2:
                continue
            tokens.append(word.lower())
    return tokens

# %%
# %%time
# training
count_vectorizer = CountVectorizer(
    analyzer="word", tokenizer=nltk.word_tokenize,
    preprocessor=None, stop_words='english', max_features=3000) 
train_data_features = count_vectorizer.fit_transform(train_data['plot'])
# Out:
# Wall time: 1.29 s

# %% [markdown]
# Multi-modal logistic regression is a simple white-box classifier. We will use either logistic regression or KNN throughout this tutorial.

# %%
# %%time

logreg = linear_model.LogisticRegression(n_jobs=1, C=1e5)
logreg = logreg.fit(train_data_features, train_data['tag'])
# Out:
# Wall time: 513 ms
# C:\Users\shoai\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
count_vectorizer.get_feature_names()[80:90]
# Out:
# ['advanced',
#  'advantage',
#  'adventure',
#  'adventures',
#  'adventurous',
#  'advice',
#  'affair',
#  'affairs',
#  'affect',
#  'afraid']

# %% [markdown]
# Nothing impressive - only 2% better better than the classifier that thinks that everything is a comedy.

# %%
# %%time

predict(count_vectorizer, logreg, test_data)
# Out:
# accuracy 0.448559670781893
# confusion matrix
#  [[23  1 12  0  3  3]
#  [ 4 11  9  0  3  4]
#  [11  7 50  2 16  0]
#  [ 4  4  1  3  3  1]
#  [ 1  3 18  1  9  3]
#  [ 9  3  6  2  0 13]]
# (row=expected, col=predicted)
# Wall time: 292 ms

# %% [markdown]
# White box vectorizer and classifier are great! We can see what are the most important words for sci-fi. This makes it very easy to tune and debug.

# %%
def most_influential_words(vectorizer, genre_index=0, num_words=10):
    features = vectorizer.get_feature_names()
    max_coef = sorted(enumerate(logreg.coef_[genre_index]), key=lambda x:x[1], reverse=True)
    return [features[x[0]] for x in max_coef[:num_words]]

# %%
# words for the fantasy genre
genre_tag_id = 1
print(my_tags[genre_tag_id])
most_influential_words(count_vectorizer, genre_tag_id)
# Out:
# action
# ['animated',
#  'tale',
#  'forest',
#  'animals',
#  'adventurous',
#  'anna',
#  'snow',
#  'halloween',
#  'taken',
#  'victor']

# %%
train_data_features[0]
# Out:
# <1x3000 sparse matrix of type '<class 'numpy.int64'>'
# 	with 43 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ### Character N-grams

# %% [markdown]
# A character _n-gram_ is a chunk of a document of length _n_. It is a poor man's tokenizer but sometimes works well. The parameter _n_ depends on language and the corpus. We choose length between 3 and 6 characters and to only focus on 3k most popular ones.

# %%
# %%time
n_gram_vectorizer = CountVectorizer(
    analyzer="char",
    ngram_range=([2,5]),
    tokenizer=None,    
    preprocessor=None,                               
    max_features=3000) 

logreg = linear_model.LogisticRegression(n_jobs=1, C=1e5)

train_data_features = n_gram_vectorizer.fit_transform(train_data['plot'])

logreg = logreg.fit(train_data_features, train_data['tag'])
# Out:
# Wall time: 6.1 s
# C:\Users\shoai\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
n_gram_vectorizer.get_feature_names()[50:60]
# Out:
# [' are ',
#  ' as',
#  ' as ',
#  ' as a',
#  ' as t',
#  ' ass',
#  ' at',
#  ' at ',
#  ' at t',
#  ' att']

# %% [markdown]
# The results are worse than using a tokenizer and bag of words. Probably due to not removing the stop words.

# %%
predict(n_gram_vectorizer, logreg, test_data)
# Out:
# accuracy 0.43209876543209874
# confusion matrix
#  [[20  2 11  1  4  4]
#  [ 4  7  9  4  2  5]
#  [11  9 43  4 16  3]
#  [ 2  3  3  4  2  2]
#  [ 6  1 11  1 14  2]
#  [ 3  2  7  4  0 17]]
# (row=expected, col=predicted)

# %% [markdown]
# ### TF-IDF
#
# [Term Frequency - Inverse Document Frequency](https://en.wikipedia.org/wiki/Tf%E2%80%93idf) is a little more advanced way to count words in a document.
# It adjusts for document length, word frequency and most importantly for frequency of a particular word in a particular document.

# %%
# %%time
tf_vect = TfidfVectorizer(
    min_df=2, tokenizer=nltk.word_tokenize,
    preprocessor=None, stop_words='english')
train_data_features = tf_vect.fit_transform(train_data['plot'])

logreg = linear_model.LogisticRegression(n_jobs=1, C=1e5)
logreg = logreg.fit(train_data_features, train_data['tag'])
# Out:
# Wall time: 2.4 s
# C:\Users\shoai\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
tf_vect.get_feature_names()[1000:1010]
# Out:
# ['cabin',
#  'cable',
#  'cadets',
#  'caesar',
#  'cage',
#  'caine',
#  'cal',
#  'calhoun',
#  'california',
#  'californians']

# %%
predict(tf_vect, logreg, test_data)
# Out:
# accuracy 0.4773662551440329
# confusion matrix
#  [[25  1 11  1  2  2]
#  [ 4  9 10  2  4  2]
#  [ 7  6 53  0 19  1]
#  [ 5  5  2  3  0  1]
#  [ 1  1 21  0 10  2]
#  [ 8  2  5  2  0 16]]
# (row=expected, col=predicted)

# %% [markdown]
# White box vectorizer and classifier are great! We can see what are the most important words for sci-fi. This makes it very easy to tune and debug.

# %%
most_influential_words(tf_vect, 1)
# Out:
# ['animated',
#  'forest',
#  'tale',
#  'halloween',
#  'animals',
#  'adventurous',
#  'anna',
#  'order',
#  'dog',
#  'prince']

# %% [markdown]
# ### Things to try with bag of words
#
# 10 mins for exercises.
#
# For more insight into the model print out the most influential words for a particular plot.
#
# Try n-grams with TF-IDF.

# %% [markdown]
# # Averaging word vectors

# %% [markdown]
# Now let's use more complex features rather than just counting words.
#
# A great recent achievement of NLP is the [word2vec embedding](https://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). See Chris Moody's [video](https://www.youtube.com/watch?v=vkfXBGnDplQ) for a great introduction to word2vec.

# %% [markdown]
# First we load a word2vec model. It has been pre-trained by Google on a 100 billon word Google News corpus. You can play with this model using a fun [web-app](http://rare-technologies.com/word2vec-tutorial/#app).
#
# Link to the web-app: http://rare-technologies.com/word2vec-tutorial/#app
#
# Vocabulary size: 3 mln words.
#
# __Warning__: 3 mins to load, takes 4 GB of RAM.

# %%
# %%time
from gensim.scripts.glove2word2vec import glove2word2vec
import os
glove2word2vec(glove_input_file="data\\vectors.10.txt", word2vec_output_file="data\gensim_glove_vectors.txt")
wv = gensim.models.KeyedVectors.load_word2vec_format( "data\gensim_glove_vectors.txt", binary=False)
os.remove('data\gensim_glove_vectors.txt')
wv.init_sims(replace=True)
# Out:
# 2021-02-05 19:02:13,334 : INFO : converting 71291 vectors from data\vectors.10.txt to data\gensim_glove_vectors.txt
# 2021-02-05 19:02:13,382 : INFO : loading projection weights from data\gensim_glove_vectors.txt
# 2021-02-05 19:02:14,581 : INFO : loaded (71291, 10) matrix from data\gensim_glove_vectors.txt
# 2021-02-05 19:02:15,334 : INFO : precomputing L2-norms of word weight vectors
# Wall time: 2.02 s

# %%
wv.vector_size
# Out:
# 10

# %% [markdown]
# Example vocabulary

# %%
from itertools import islice
list(islice(wv.vocab, 13000, 13020))
# Out:
# ['mammoth',
#  'manifested',
#  'maxim',
#  'mixtures',
#  'modelled',
#  'mot',
#  'multinational',
#  'nationalities',
#  'neighbourhood',
#  'niven',
#  'novelty',
#  'oecd',
#  'packard',
#  'parentheses',
#  'partement',
#  'peaked',
#  'plausible',
#  'prompting',
#  'rca',
#  'readable']

# %% [markdown]
# Now we have a vector for each word. How do we get a vector for a sequence of words (aka a document)?

# %% [markdown]
# The most naive way is just to take an average. [Mike Tamir](https://www.youtube.com/watch?v=7gTjYwiaJiU) has suggested that the resulting vector points to a single word summarising the whole document. For example all words in a book
#  ‘A tale of two cities’ should add up to 'class-struggle’

# %% [markdown]
# <img src="images/naivedoc2vec.png">

# %%
def word_averaging(wv, words):
    all_words, mean = set(), []
    
    for word in words:
        if isinstance(word, np.ndarray):
            mean.append(word)
        elif word in wv.vocab:
            mean.append(wv.syn0norm[wv.vocab[word].index])
            all_words.add(wv.vocab[word].index)

    if not mean:
        logging.warning("cannot compute similarity with no input %s", words)
        # FIXME: remove these examples in pre-processing
        return np.zeros(wv.layer1_size,)

    mean = gensim.matutils.unitvec(np.array(mean).mean(axis=0)).astype(np.float32)
    return mean

def  word_averaging_list(wv, text_list):
    return np.vstack([word_averaging(wv, review) for review in text_list ])

# %% [markdown]
# For word2vec we apply a different tokenization. We want to preserve case as the vocabulary distingushes lower and upper case.

# %%
def w2v_tokenize_text(text):
    tokens = []
    for sent in nltk.sent_tokenize(text, language='english'):
        for word in nltk.word_tokenize(sent, language='english'):
            if len(word) < 2:
                continue
            tokens.append(word)
    return tokens

# %%
test_tokenized = test_data.apply(lambda r: w2v_tokenize_text(r['plot']), axis=1).values
train_tokenized = train_data.apply(lambda r: w2v_tokenize_text(r['plot']), axis=1).values

# %%
# %%time
X_train_word_average = word_averaging_list(wv,train_tokenized)
X_test_word_average = word_averaging_list(wv,test_tokenized)
# Out:
# <ipython-input-97-b93e2c1d24eb>:8: DeprecationWarning: Call to deprecated `syn0norm` (Attribute will be removed in 4.0.0, use self.vectors_norm instead).
#   mean.append(wv.syn0norm[wv.vocab[word].index])
# Wall time: 637 ms

# %% [markdown]
# Let's see how KNN and logistic regression classifiers perform on these word-averaging document features.

# %%
# %%time
knn_naive_dv = KNeighborsClassifier(n_neighbors=3, n_jobs=1, algorithm='brute', metric='cosine' )
knn_naive_dv.fit(X_train_word_average, train_data.tag)
# Out:
# Wall time: 2.98 ms
# KNeighborsClassifier(algorithm='brute', metric='cosine', n_jobs=1,
#                      n_neighbors=3)

# %%
# %%time
predicted = knn_naive_dv.predict(X_test_word_average)
# Out:
# Wall time: 32.6 ms

# %%
evaluate_prediction(predicted, test_data.tag)
# Out:
# accuracy 0.27983539094650206
# confusion matrix
#  [[15  4 13  4  1  5]
#  [10  4  9  3  4  1]
#  [18 16 35  3 13  1]
#  [ 6  3  2  2  3  0]
#  [10  5  9  1  7  3]
#  [14  7  5  1  1  5]]
# (row=expected, col=predicted)

# %% [markdown]
# KNN is even worse than the naive 'everything is comedy' baseline! Let's see if logistic regression is better.

# %%
# %%time
logreg = linear_model.LogisticRegression(n_jobs=1, C=1e5)

logreg = logreg.fit(X_train_word_average, train_data['tag'])
predicted = logreg.predict(X_test_word_average)
# Out:
# Wall time: 168 ms
# C:\Users\shoai\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# Great! It gives __54%__ accuracy. Best that we have seen so far.

# %%
evaluate_prediction(predicted, test_data.tag)
# Out:
# accuracy 0.39094650205761317
# confusion matrix
#  [[ 9  2 27  0  0  4]
#  [ 2  3 19  0  4  3]
#  [ 5  2 67  1  6  5]
#  [ 3  1  9  0  1  2]
#  [ 1  1 26  0  4  3]
#  [ 4  1 16  0  0 12]]
# (row=expected, col=predicted)

# %% [markdown]
# Now just for fun let's see if text summarisation works on our data. Let's pick a plot and see which words it averages to.

# %%
test_data.iloc()[56]['plot']
# Out:
# 'Scruffy but irresistibly attractive Yau Muk-yan, without a job or a place to live, moves in with sensitive, shy piano tuner Chan Kar-fu. Both are disturbed, then obsessed, by the amateurish piano playing of upstairs neighbour Mok Man-yee. Obsession turns to romance, and romance to fantasy. The film is structured in four "movements": two themes (Yau Muk-yan, Mok Man-yee), a duet (Yau Muk-yan & Mok Man-yee), and a set of variations (a wild fantasy of Chan Kar-fu in his new novel).'

# %% [markdown]
# Hmm... The summarisation doesn't work here. Any ideas why? Hint: look at the area where the average ends up.

# %%
wv.most_similar(positive=[X_test_word_average[56]], restrict_vocab=100000, topn=30)[0:20]
# Out:
# [('with', 0.9648395776748657),
#  ('well', 0.9646797180175781),
#  ('another', 0.9588462710380554),
#  ('about', 0.9579797983169556),
#  ('shown', 0.9567312002182007),
#  ('seen', 0.9560493230819702),
#  ('course', 0.9557462930679321),
#  ('as', 0.9534212350845337),
#  ('very', 0.9529887437820435),
#  ('good', 0.95225590467453),
#  ('while', 0.9520713686943054),
#  ('events', 0.9498836994171143),
#  ('though', 0.9480241537094116),
#  ('making', 0.9471138119697571),
#  ('more', 0.9470860958099365),
#  ('even', 0.9459554553031921),
#  ('there', 0.9456855058670044),
#  ('little', 0.9454309344291687),
#  ('often', 0.9439430832862854),
#  ('life', 0.9437060356140137)]

# %% [markdown]
# ### Word2vec things to try

# %% [markdown]
# 10 mins exercise
#
# Remove stop-words.

# %%
def w2v_tokenize_text(text):
    tokens = []
    for sent in nltk.sent_tokenize(text, language='english'):
        for word in nltk.word_tokenize(sent, language='english'):
            if len(word) < 2:
                continue
            if word in stopwords.words('english'):
                continue
            tokens.append(word)
    return tokens

# %% [markdown]
# ### What accuracy do you get?

# %%
### More word2vec things to try

Experiment with other pre-trained models - see nice [list](https://github.com/3Top/word2vec-api/) from 3Top.


Use Gensim's GloVe converter.


Do IDF weighting in the averaging function.
# Out:
#   File "<ipython-input-109-5aee0a3c5924>", line 3
#     Experiment with other pre-trained models - see nice [list](https://github.com/3Top/word2vec-api/) from 3Top.
#                ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Doc2Vec

# %% [markdown]
# A [paper](https://cs.stanford.edu/~quocle/paragraph_vector.pdf) by Google suggests a model for document classification called Paragraph Vectors Doc2Vec or Doc2vec in short. It is very similar to word2vec.
#
# It introduces 'a tag' - a word that is in every context in the document.
#
# For our first try we tag every plot with its genre. This makes it 'semi-supervised' learning - the genre labels is just one objective among many.

# %%
from gensim.models import Doc2Vec
from gensim.models.doc2vec import TaggedDocument

# %%
train_tagged = train_data.apply(
    lambda r: TaggedDocument(words=tokenize_text(r['plot']), tags=[r.tag]), axis=1)

# %%
test_tagged = test_data.apply(
    lambda r: TaggedDocument(words=tokenize_text(r['plot']), tags=[r.tag]), axis=1)

# %% [markdown]
# This is what a training entry looks like - an example plot tagged by 'sci-fi'.

# %%
test_tagged.values[50]
# Out:
# TaggedDocument(words=['troubled', 'psychologist', 'is', 'sent', 'to', 'investigate', 'the', 'crew', 'of', 'an', 'isolated', 'research', 'station', 'orbiting', 'bizarre', 'planet'], tags=['sci-fi'])

# %%
# %%time
trainsent = train_tagged.values
testsent = test_tagged.values

# simple gensim doc2vec api
doc2vec_model = Doc2Vec(trainsent, workers=1, size=5, iter=20, dm=1)

train_targets, train_regressors = zip(
    *[(doc.tags[0], doc2vec_model.infer_vector(doc.words, steps=20)) for doc in trainsent])
# Out:
# C:\Users\shoai\anaconda3\lib\site-packages\gensim\models\doc2vec.py:315: UserWarning: The parameter `iter` is deprecated, will be removed in 4.0.0, use `epochs` instead.
#   warnings.warn("The parameter `iter` is deprecated, will be removed in 4.0.0, use `epochs` instead.")
# C:\Users\shoai\anaconda3\lib\site-packages\gensim\models\doc2vec.py:319: UserWarning: The parameter `size` is deprecated, will be removed in 4.0.0, use `vector_size` instead.
#   warnings.warn("The parameter `size` is deprecated, will be removed in 4.0.0, use `vector_size` instead.")
# 2021-02-05 18:20:24,163 : WARNING : consider setting layer size to a multiple of 4 for greater performance
# 2021-02-05 18:20:24,164 : INFO : collecting all words and their counts
# 2021-02-05 18:20:24,165 : INFO : PROGRESS: at example #0, processed 0 words (0/s), 0 word types, 0 tags
# 2021-02-05 18:20:24,219 : INFO : collected 17160 word types and 6 unique tags from a corpus of 2184 examples and 150646 words
# 2021-02-05 18:20:24,221 : INFO : Loading a fresh vocabulary
# 2021-02-05 18:20:24,234 : INFO : effective_min_count=5 retains 3634 unique words (21% of original 17160, drops 13526)
# 2021-02-05 18:20:24,236 : INFO : effective_min_count=5 leaves 128974 word corpus (85% of original 150646, drops 21672)
# 2021-02-05 18:20:24,249 : INFO : deleting the raw counts dictionary of 17160 items
# 2021-02-05 18:20:24,250 : INFO : sample=0.001 downsamples 43 most-common words
# 2021-02-05 18:20:24,252 : INFO : downsampling leaves estimated 92803 word corpus (72.0% of prior 128974)
# 2021-02-05 18:20:24,267 : INFO : estimated required memory for 3634 words and 5 dimensions: 1963680 bytes
# 2021-02-05 18:20:24,270 : INFO : resetting layer weights
# 2021-02-05 18:20:25,080 : INFO : training model with 1 workers on 3634 vocabulary and 5 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# 2021-02-05 18:20:25,368 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-05 18:20:25,369 : INFO : EPOCH - 1 : training on 150646 raw words (95037 effective words) took 0.3s, 331997 effective words/s
# 2021-02-05 18:20:25,663 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-05 18:20:25,664 : INFO : EPOCH - 2 : training on 150646 raw words (94897 effective words) took 0.3s, 326133 effective words/s
# 2021-02-05 18:20:25,957 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-05 18:20:25,957 : INFO : EPOCH - 3 : training on 150646 raw words (94818 effective words) took 0.3s, 325905 effective words/s
# 2021-02-05 18:20:26,185 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-05 18:20:26,186 : INFO : EPOCH - 4 : training on 150646 raw words (95154 effective words) took 0.2s, 421563 effective words/s
# 2021-02-05 18:20:26,418 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-05 18:20:26,420 : INFO : EPOCH - 5 : training on 150646 raw words (95112 effective words) took 0.2s, 411465 effective words/s
# 2021-02-05 18:20:26,651 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-05 18:20:26,652 : INFO : EPOCH - 6 : training on 150646 raw words (94903 effective words) took 0.2s, 413250 effective words/s
# 2021-02-05 18:20:26,896 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-05 18:20:26,898 : INFO : EPOCH - 7 : training on 150646 raw words (94940 effective words) took 0.2s, 390325 effective words/s
# 2021-02-05 18:20:27,136 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-05 18:20:27,137 : INFO : EPOCH - 8 : training on 150646 raw words (95236 effective words) took 0.2s, 401430 effective words/s
# 2021-02-05 18:20:27,378 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-05 18:20:27,380 : INFO : EPOCH - 9 : training on 150646 raw words (94876 effective words) took 0.2s, 395983 effective words/s
# 2021-02-05 18:20:27,620 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-05 18:20:27,621 : INFO : EPOCH - 10 : training on 150646 raw words (94906 effective words) took 0.2s, 397401 effective words/s
# 2021-02-05 18:20:27,864 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-05 18:20:27,865 : INFO : EPOCH - 11 : training on 150646 raw words (95126 effective words) took 0.2s, 394265 effective words/s
# 2021-02-05 18:20:28,158 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-05 18:20:28,159 : INFO : EPOCH - 12 : training on 150646 raw words (95026 effective words) took 0.3s, 325242 effective words/s
# 2021-02-05 18:20:28,450 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-05 18:20:28,451 : INFO : EPOCH - 13 : training on 150646 raw words (94904 effective words) took 0.3s, 327758 effective words/s
# 2021-02-05 18:20:28,752 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-05 18:20:28,754 : INFO : EPOCH - 14 : training on 150646 raw words (94902 effective words) took 0.3s, 318351 effective words/s
# 2021-02-05 18:20:29,052 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-05 18:20:29,054 : INFO : EPOCH - 15 : training on 150646 raw words (94896 effective words) took 0.3s, 320402 effective words/s
# 2021-02-05 18:20:29,286 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-05 18:20:29,288 : INFO : EPOCH - 16 : training on 150646 raw words (95117 effective words) took 0.2s, 412765 effective words/s
# 2021-02-05 18:20:29,515 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-05 18:20:29,516 : INFO : EPOCH - 17 : training on 150646 raw words (94974 effective words) took 0.2s, 420969 effective words/s
# 2021-02-05 18:20:29,744 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-05 18:20:29,745 : INFO : EPOCH - 18 : training on 150646 raw words (94795 effective words) took 0.2s, 420147 effective words/s
# 2021-02-05 18:20:29,972 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-05 18:20:29,973 : INFO : EPOCH - 19 : training on 150646 raw words (95031 effective words) took 0.2s, 419843 effective words/s
# 2021-02-05 18:20:30,206 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-05 18:20:30,206 : INFO : EPOCH - 20 : training on 150646 raw words (95075 effective words) took 0.2s, 412649 effective words/s
# 2021-02-05 18:20:30,207 : INFO : training on a 3012920 raw words (1899725 effective words) took 5.1s, 370568 effective words/s
# Wall time: 10.4 s

# %% [markdown]
# Interesting thing about doc2vec is that we need to run gradient descent during prediction to infer the vector for an unseen document. An unseen document is initially assigned a random vector and then this vector fit by gradient descent. Because of this randomness we get different vectors on re-runs of the next cell.
#
# Consequently, the accuracy of logistic regression changes when the test set vectors change.

# %%
# %%time
test_targets, test_regressors = zip(
    *[(doc.tags[0], doc2vec_model.infer_vector(doc.words, steps=20)) for doc in testsent])
# Out:
# Wall time: 453 ms

# %%
logreg = linear_model.LogisticRegression(n_jobs=1, C=1e5)
logreg = logreg.fit(train_regressors, train_targets)
evaluate_prediction(logreg.predict(test_regressors), test_targets, title=str(doc2vec_model))
# Out:
# accuracy 0.5061728395061729
# confusion matrix
#  [[24  1 11  0  2  4]
#  [ 1 10 10  0  6  4]
#  [ 9  4 59  0 12  2]
#  [ 3  4  4  2  2  1]
#  [ 2  0 20  0 11  2]
#  [ 8  4  4  0  0 17]]
# (row=expected, col=predicted)

# %% [markdown]
# KNN gives a lower accuracy than logistic regression.

# %%
# %%time 
knn_test_predictions = [
    doc2vec_model.docvecs.most_similar([pred_vec], topn=1)[0][0]
    for pred_vec in test_regressors
]
evaluate_prediction(knn_test_predictions, test_targets, str(doc2vec_model))
# Out:
# 2021-02-05 18:20:42,121 : INFO : precomputing L2-norms of doc weight vectors
# accuracy 0.3662551440329218
# confusion matrix
#  [[19  5  2  0  6 10]
#  [ 2 14  1  0 10  4]
#  [14 11 18  0 41  2]
#  [ 2  8  2  0  2  2]
#  [ 4  6  4  0 21  0]
#  [ 6  7  0  0  3 17]]
# (row=expected, col=predicted)
# Wall time: 131 ms

# %% [markdown]
# Doc2vec gives us a vector for each genre so we can see which genres are close together.

# %%
doc2vec_model.docvecs.most_similar('action')
# Out:
# [('sci-fi', 0.6294103264808655),
#  ('comedy', 0.6070477962493896),
#  ('animation', 0.10011281073093414),
#  ('fantasy', -0.0047411322593688965),
#  ('romance', -0.026120446622371674)]

# %% [markdown]
# Words surrounding the 'sci-fi' tag describe it pretty accurately!

# %%
doc2vec_model.most_similar([doc2vec_model.docvecs['sci-fi']])
# Out:
# <ipython-input-72-62a4185a5e3b>:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   doc2vec_model.most_similar([doc2vec_model.docvecs['sci-fi']])
# 2021-02-05 18:20:46,681 : INFO : precomputing L2-norms of word weight vectors
# [('world', 0.9883897304534912),
#  ('alien', 0.9883082509040833),
#  ('soviets', 0.9849703311920166),
#  ('planet', 0.9814175367355347),
#  ('virus', 0.9779919981956482),
#  ('ship', 0.9758446216583252),
#  ('radiation', 0.9712104797363281),
#  ('worldwide', 0.9676659107208252),
#  ('earth', 0.9638729095458984),
#  ('psychic', 0.963219165802002)]

# %% [markdown]
# ### Doc2vec exercise
#
# 10 mins
#
# Find the random seed that gives the best prediction. :)

# %%
seed = 20

doc2vec_model.seed = seed
doc2vec_model.random = random.RandomState(seed)


test_targets, test_regressors = zip(
    *[(doc.tags[0], doc2vec_model.infer_vector(doc.words, steps=20)) for doc in testsent])


logreg = linear_model.LogisticRegression(n_jobs=1, C=1e5, random_state=42)
logreg = logreg.fit(train_regressors, train_targets)
evaluate_prediction(logreg.predict(test_regressors), test_targets, title=str(doc2vec_model))
print(doc2vec_model.seed)
# Out:
# accuracy 0.51440329218107
# confusion matrix
#  [[23  2 11  0  2  4]
#  [ 3  9  9  1  5  4]
#  [ 8  3 61  0 12  2]
#  [ 1  4  4  1  3  3]
#  [ 3  0 17  0 14  1]
#  [ 9  2  5  0  0 17]]
# (row=expected, col=predicted)
# 20

# %% [markdown]
# ## Doc2vec things to try
# Try tagging every sentence with a unique tag 'SENT_123' and then apply KNN.
#
# Try multiple tags per plot as in this repo published __today__ : https://github.com/sindbach/doc2vec_pymongo

# %% [markdown]
# # Deep IR

# %% [markdown]
# 'Deep IR' is a technique developed by  [“Document Classification by Inversion of Distributed Language Representations”, Matt Taddy](http://arxiv.org/pdf/1504.07295v3.pdf). Matt has contributed a gensim [tutorial](https://github.com/piskvorky/gensim/blob/develop/docs/notebooks/deepir.ipynb) - great source of more in depth information.
#
# In short the algorithm is:
#
# 1. Train a word2vec model only on comedy plots.
#
# 2. Trian another model only on sci-fi, another on romance etc. Get 6 models - one for each genre.
#
# 3. Take a plot and see which model fits it best using Bayes' Theorem

# %% [markdown]
# The tokenization is different from other methods. The reason for this is that we are following an original approach in the paper. The purpose of this tutorial is to see how the models behave out of the box.
#
# We just clean non-alphanumeric characters and split by sentences.

# %%
import re
contractions = re.compile(r"'|-|\"")
# all non alphanumeric
symbols = re.compile(r'(\W+)', re.U)
# single character removal
singles = re.compile(r'(\s\S\s)', re.I|re.U)
# separators (any whitespace)
seps = re.compile(r'\s+')

# cleaner (order matters)
def clean(text): 
    text = text.lower()
    text = contractions.sub('', text)
    text = symbols.sub(r' \1 ', text)
    text = singles.sub(' ', text)
    text = seps.sub(' ', text)
    return text

# sentence splitter
alteos = re.compile(r'([!\?])')
def sentences(l):
    l = alteos.sub(r' \1 .', l).rstrip("(\.)*\n")
    return l.split(".")

# %%
def plots(label):
    my_df = None
    if label=='training':
        my_df = train_data
    else:
        my_df = test_data
    for i, row in my_df.iterrows():
        yield {'y':row['tag'],\
        'x':[clean(s).split() for s in sentences(row['plot'])]}

# %%
# %%time
# The corpus is small so can be read into memory
revtrain = list(plots("training"))
revtest = list(plots("test"))
# Out:
# Wall time: 626 ms

# %%
# shuffle training set for unbiased word2vec training
np.random.shuffle(revtrain)

# %%
def tag_sentences(reviews, stars=my_tags):  
    for r in reviews:
        if r['y'] in stars:
            for s in r['x']:
                yield s

# %% [markdown]
# An example `sci-fi` sentence:

# %%
next(tag_sentences(revtrain, my_tags[0]))
# Out:
# ['astronomer', 'dr']

# %% [markdown]
# We train our own 6 word2vec models from scratch.

# %%
# %%time 
## training
from gensim.models import Word2Vec
import multiprocessing

## create a w2v learner 
basemodel = Word2Vec(
    workers=multiprocessing.cpu_count(), # use your cores
    iter=100, # iter = sweeps of SGD through the data; more is better
    hs=1, negative=0, # we only have scoring for the hierarchical softmax setup
    
    )
print(basemodel)
basemodel.build_vocab(tag_sentences(revtrain)) 
from copy import deepcopy
genremodels = [deepcopy(basemodel) for i in range(len(my_tags))]
for i in range(len(my_tags)):
    slist = list(tag_sentences(revtrain, my_tags[i]))
    print(my_tags[i], "genre (", len(slist), ")")
    genremodels[i].train( slist, total_examples=len(slist) ,epochs = basemodel.epochs)
# get the probs (note we give docprob a list of lists of words, plus the models)
# Out:
# 2021-02-05 18:21:22,596 : INFO : collecting all words and their counts
# 2021-02-05 18:21:22,597 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2021-02-05 18:21:22,640 : INFO : collected 17544 word types from a corpus of 148422 raw words and 7880 sentences
# 2021-02-05 18:21:22,642 : INFO : Loading a fresh vocabulary
# 2021-02-05 18:21:22,661 : INFO : effective_min_count=5 retains 3647 unique words (20% of original 17544, drops 13897)
# 2021-02-05 18:21:22,662 : INFO : effective_min_count=5 leaves 126255 word corpus (85% of original 148422, drops 22167)
# 2021-02-05 18:21:22,674 : INFO : deleting the raw counts dictionary of 17544 items
# 2021-02-05 18:21:22,676 : INFO : sample=0.001 downsamples 42 most-common words
# 2021-02-05 18:21:22,676 : INFO : downsampling leaves estimated 91197 word corpus (72.2% of prior 126255)
# 2021-02-05 18:21:22,681 : INFO : constructing a huffman tree from 3647 words
# 2021-02-05 18:21:22,789 : INFO : built huffman tree with maximum node depth 15
# Word2Vec(vocab=0, size=100, alpha=0.025)
# 2021-02-05 18:21:22,792 : INFO : estimated required memory for 3647 words and 100 dimensions: 5470500 bytes
# 2021-02-05 18:21:22,793 : INFO : resetting layer weights
# 2021-02-05 18:21:24,029 : INFO : training model with 8 workers on 3647 vocabulary and 100 features, using sg=0 hs=1 sample=0.001 negative=0 window=5
# 2021-02-05 18:21:24,046 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2021-02-05 18:21:24,049 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2021-02-05 18:21:24,051 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-02-05 18:21:24,052 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-02-05 18:21:24,053 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-02-05 18:21:24,054 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-05 18:21
: INFO : worker thread finished; awaiting finish of 7 more threads
# 2021-02-05 18:21:44,332 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2021-02-05 18:21:44,333 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-02-05 18:21:44,333 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-02-05 18:21:44,334 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-02-05 18:21:44,336 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-05 18:21:44,341 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-05 18:21:44,344 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-05 18:21:44,345 : INFO : EPOCH - 97 : training on 26414 raw words (16242 effective words) took 0.0s, 635528 effective words/s
# 2021-02-05 18:21:44,355 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2021-02-05 18:21:44,362 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2021-02-05 18:21:44,363 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-02-05 18:21:44,364 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-02-05 18:21:44,365 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-02-05 18:21:44,367 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-05 18:21:44,370 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-05 18:21:44,373 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-05 18:21:44,374 : INFO : EPOCH - 98 : training on 26414 raw words (16311 effective words) took 0.0s, 699137 effective words/s
# 2021-02-05 18:21:44,383 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2021-02-05 18:21:44,394 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2021-02-05 18:21:44,397 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-02-05 18:21:44,398 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-02-05 18:21:44,399 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-02-05 18:21:44,402 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-05 18:21:44,404 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-05 18:21:44,409 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-05 18:21:44,411 : INFO : EPOCH - 99 : training on 26414 raw words (16308 effective words) took 0.0s, 511797 effective words/s
# 2021-02-05 18:21:44,422 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2021-02-05 18:21:44,428 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2021-02-05 18:21:44,430 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-02-05 18:21:44,430 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-02-05 18:21:44,431 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-02-05 18:21:44,433 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-05 18:21:44,439 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-05 18:21:44,441 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-05 18:21:44,442 : INFO : EPOCH - 100 : training on 26414 raw words (16357 effective words) took 0.0s, 630843 effective words/s
# 2021-02-05 18:21:44,443 : INFO : training on a 2641400 raw words (1630106 effective words) took 3.2s, 502877 effective words/s
# Wall time: 21.8 s

# %% [markdown]
# Now we will compute most likely class for a plot using Bayes' Theorem formula.

# %% [markdown]
# <img src='images/deep_ir_bayes.png' width=600>

# %% [markdown]
# For any new sentence we can obtain its _likelihood_ (lhd; actually, the composite likelihood approximation; see the paper) using the [score](https://radimrehurek.com/gensim/models/word2vec.html#gensim.models.word2vec.Word2Vec.score) function in the `word2vec` class.  We get the likelihood for each sentence in the first test review, then convert to a probability over star ratings. Every sentence in the review is evaluated separately and the final star rating of the review is an average vote of all the sentences. This is all in the following handy wrapper. (from the original [tutorial](https://github.com/piskvorky/gensim/blob/develop/docs/notebooks/deepir.ipynb) by Matt Taddy.

# %%
"""
docprob takes two lists
* docs: a list of documents, each of which is a list of sentences
* models: the candidate word2vec models (each potential class)

it returns the array of class probabilities.  Everything is done in-memory.
"""


def docprob(docs, mods):
    # score() takes a list [s] of sentences here; could also be a sentence generator
    sentlist = [s for d in docs for s in d]
    # the log likelihood of each sentence in this review under each w2v representation
    llhd = np.array( [ m.score(sentlist, len(sentlist)) for m in mods ] )
    # now exponentiate to get likelihoods, 
    lhd = np.exp(llhd - llhd.max(axis=0)) # subtract row max to avoid numeric overload
    # normalize across models (stars) to get sentence-star probabilities
    prob = pd.DataFrame( (lhd/lhd.sum(axis=0)).transpose() )
    # and finally average the sentence probabilities to get the review probability
    prob["doc"] = [i for i,d in enumerate(docs) for s in d]
    prob = prob.groupby("doc").mean()
    return prob

# %%
# %%time
## predict
probs = docprob( [r['x'] for r in revtest], genremodels )  
predictions = probs.idxmax(axis=1).apply(lambda x: my_tags[x])
# Out:
# 2021-02-05 18:22:04,778 : INFO : scoring sentences with 8 workers on 3647 vocabulary and 100 features, using sg=0 hs=1 sample=0.001 and negative=0
# 2021-02-05 18:22:04,784 : INFO : reached end of input; waiting to finish 9 outstanding jobs
# 2021-02-05 18:22:04,807 : INFO : scoring 894 sentences took 0.0s, 32469 sentences/s
# 2021-02-05 18:22:04,809 : INFO : scoring sentences with 8 workers on 3647 vocabulary and 100 features, using sg=0 hs=1 sample=0.001 and negative=0
# 2021-02-05 18:22:04,812 : INFO : reached end of input; waiting to finish 9 outstanding jobs
# 2021-02-05 18:22:04,833 : INFO : scoring 894 sentences took 0.0s, 37569 sentences/s
# 2021-02-05 18:22:04,834 : INFO : scoring sentences with 8 workers on 3647 vocabulary and 100 features, using sg=0 hs=1 sample=0.001 and negative=0
# 2021-02-05 18:22:04,838 : INFO : reached end of input; waiting to finish 9 outstanding jobs
# 2021-02-05 18:22:04,861 : INFO : scoring 894 sentences took 0.0s, 33954 sentences/s
# 2021-02-05 18:22:04,863 : INFO : scoring sentences with 8 workers on 3647 vocabulary and 100 features, using sg=0 hs=1 sample=0.001 and negative=0
# 2021-02-05 18:22:04,867 : INFO : reached end of input; waiting to finish 9 outstanding jobs
# 2021-02-05 18:22:04,894 : INFO : scoring 894 sentences took 0.0s, 29727 sentences/s
# 2021-02-05 18:22:04,896 : INFO : scoring sentences with 8 workers on 3647 vocabulary and 100 features, using sg=0 hs=1 sample=0.001 and negative=0
# 2021-02-05 18:22:04,902 : INFO : reached end of input; waiting to finish 9 outstanding jobs
# 2021-02-05 18:22:04,925 : INFO : scoring 894 sentences took 0.0s, 31411 sentences/s
# 2021-02-05 18:22:04,927 : INFO : scoring sentences with 8 workers on 3647 vocabulary and 100 features, using sg=0 hs=1 sample=0.001 and negative=0
# 2021-02-05 18:22:04,931 : INFO : reached end of input; waiting to finish 9 outstanding jobs
# 2021-02-05 18:22:04,957 : INFO : scoring 894 sentences took 0.0s, 30820 sentences/s
# Wall time: 189 ms

# %%
tag_index = 0
col_name = "out-of-sample prob positive for " + my_tags[tag_index]
probpos = pd.DataFrame({col_name:probs[[tag_index]].sum(axis=1), 
                        "true genres": [r['y'] for r in revtest]})
probpos.boxplot(col_name,by="true genres", figsize=(12,5))
# Out:
# <AxesSubplot:title={'center':'out-of-sample prob positive for sci-fi'}, xlabel='true genres'>

# %%
target = [r['y'] for r in revtest]

# %%
evaluate_prediction(predictions, target, "Deep IR with word2vec")
# Out:
# accuracy 0.32510288065843623
# confusion matrix
#  [[13  5  7  3  8  6]
#  [ 3  5  6  7  7  3]
#  [ 4 12 31 10 18 11]
#  [ 3  3  2  3  2  3]
#  [ 4  3 10  2 13  3]
#  [ 2  7  5  2  3 14]]
# (row=expected, col=predicted)

# %% [markdown]
# Performance is worse than for a naive predictor that says that everything is `comedy`.
#
# ### Why?

# %% [markdown]
# It is because we train each word2vec model from scratch on a very small sample of about 30k words.
#
# This model needs more data.

# %% [markdown]
# # Conclusion

# %% [markdown]
# Above we shown how to run 'hello-world' in 7 different document classification techniques. It is just a beginning of exploration of their features... There are a lot of parameters that can be tuned to get the best possible results out of them. The 'hello-world' run is in no way an indication of their best peformance. The goal of this tutorial is to show the API so you can start tuning them yourself.

# %% [markdown]
# Out of the box "no tuning" accuracy of bag of words is not far behind more advanced techniques.
# Tune them and the pre-processing for them well first and only then reach for more advanced methods if more accuracy is absolutely needed.
